# %%
import pandas as pd
import seaborn as sn
import matplotlib as mpl

# %%
bigPremTeamData22x23 = pd.read_html('https://fbref.com/en/comps/9/Premier-League-Stats')

# %%
premStandings22x23 = bigPremTeamData22x23[0]
premStandStats22x23 = bigPremTeamData22x23[2]
premShotStats22x23 = bigPremTeamData22x23[8]
premPassStats22x23 = bigPremTeamData22x23[10]
premPassTypes22x23 = bigPremTeamData22x23[12]
premGoalxShotCreation22x23 = bigPremTeamData22x23[14]
premDefenseStats22x23 = bigPremTeamData22x23[16]
premPossesionStats22x23 = bigPremTeamData22x23[18]

# %%
premStandings22x23.head()
# Out:
#    Rk            Squad  MP   W   D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0   1          Arsenal  28  22   3  3  66  26  40   69    2.46  53.8  27.0
# 1   2  Manchester City  27  19   4  4  67  25  42   61    2.26  56.1  21.5
# 2   3   Manchester Utd  26  15   5  6  41  35   6   50    1.92  40.8  32.6
# 3   4        Tottenham  28  15   4  9  52  40  12   49    1.75  41.0  33.8
# 4   5    Newcastle Utd  26  12  11  3  39  19  20   47    1.81  41.7  24.9
#
#     xGD  xGD/90     Last 5  Attendance       Top Team Scorer      Goalkeeper  \
# 0  26.7    0.95  W W W W W       60199       Martinelli - 13  Aaron Ramsdale
# 1  34.6    1.28  W D W W W       53219   Erling Haaland - 28         Ederson
# 2   8.2    0.31  D W W L D       73749  Marcus Rashford - 14    David de Gea
# 3   7.2    0.26  W W L W D       61654       Harry Kane - 21     Hugo Lloris
# 4  16.8    0.65  D L L W W       52241   Miguel Almirón - 11       Nick Pope
#
#    Notes
# 0    NaN
# 1    NaN
# 2    NaN
# ...

# %%
premStandStats22x23.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                Squad               # Pl                Age               Poss
# 0            Arsenal                 26               25.1               60.1
# 1        Aston Villa                 26               27.6               49.1
# 2        Bournemouth                 30               27.0               38.4
# 3          Brentford                 25               26.9               44.3
# 4           Brighton                 25               27.4               59.1
#
#   Playing Time                    Performance      ... Per 90 Minutes        \
#             MP Starts   Min   90s         Gls Ast  ...            Gls   Ast
# 0           28    308  2520  28.0          63  48  ...           2.25  1.71
# 1           27    297  2430  27.0          33  23  ...           1.22  0.85
# 2           27    297  2430  27.0          25  19  ...           0.93  0.70
# ...

# %%
premPossesionStats22x23.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                Squad               # Pl               Poss                90s
# 0            Arsenal                 26               60.1               28.0
# 1        Aston Villa                 26               49.1               27.0
# 2        Bournemouth                 30               38.4               27.0
# 3          Brentford                 25               44.3               27.0
# 4           Brighton                 25               59.1               25.0
#
#   Touches                                          ... Carries          \
#   Touches Def Pen Def 3rd Mid 3rd Att 3rd Att Pen  ... Carries TotDist
# 0   19372    1389    4754    8647    6111     993  ...   11859   63408
# 1   15664    1917    5686    6704    3418     529  ...    8900   45478
# 2   13570    2105    5625    5291    2836     453  ...    6810   37010
# ...

# %%
premPlayerShootingStats22x23 = pd.read_csv('premPlayerShotStats22x23.csv')
# Out:
#   File "<ipython-input-21-cd4204d64d20>", line 1
#     premPlayerShootingStats22x23 = pd.read_csv(,,,,,,,,Standard,Standard,Standard,Standard,Standard,Standard,Standard,Standard,Standard,Standard,Standard,Standard,Expected,Expected,Expected,Expected,Expected,,-additional
#                                                ^
# SyntaxError: invalid syntax

# %%
premPlayerShootingStats22x23 = premPlayerShootingStats22x23[1]

# %%
premPlayerShootingStats22x23.head()
